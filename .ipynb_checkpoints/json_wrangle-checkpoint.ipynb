# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
from pandas.io.json import json_normalize

# %%
#We are working with processed world bank project data
with open('data/world_bank_projects.json') as data_file:    
    world_bank_data = json.load(data_file) #Load it up for analysis

# %%
#Load and check out the columns
json_df = pd.DataFrame(world_bank_data)
json_df.columns
# Out:
# Index(['_id', 'approvalfy', 'board_approval_month', 'boardapprovaldate',
#        'borrower', 'closingdate', 'country_namecode', 'countrycode',
#        'countryname', 'countryshortname', 'docty', 'envassesmentcategorycode',
#        'grantamt', 'ibrdcommamt', 'id', 'idacommamt', 'impagency',
#        'lendinginstr', 'lendinginstrtype', 'lendprojectcost',
#        'majorsector_percent', 'mjsector_namecode', 'mjtheme',
#        'mjtheme_namecode', 'mjthemecode', 'prodline', 'prodlinetext',
#        'productlinetype', 'project_abstract', 'project_name', 'projectdocs',
#        'projectfinancialtype', 'projectstatusdisplay', 'regionname', 'sector',
#        'sector1', 'sector2', 'sector3', 'sector4', 'sector_namecode',
#        'sectorcode', 'source', 'status', 'supplementprojectflg', 'theme1',
#        'theme_namecode', 'themecode', 'totalamt', 'totalcommamt', 'url'],
#       dtype='object')

# %%
#There are a lot of data, so let's remove some of them
json_df_less = json_df[['_id', 'boardapprovaldate',
                        'countryname', 'countryshortname',
                        'mjtheme_namecode', 'project_name',
                        'totalamt']]
json_df_less.head(5)
# Out:
#                                       _id     boardapprovaldate  \
# 0    {'$oid': '52b213b38594d8a2be17c780'}  2013-11-12T00:00:00Z
# 1    {'$oid': '52b213b38594d8a2be17c781'}  2013-11-04T00:00:00Z
# 2    {'$oid': '52b213b38594d8a2be17c782'}  2013-11-01T00:00:00Z
# 3    {'$oid': '52b213b38594d8a2be17c783'}  2013-10-31T00:00:00Z
# 4    {'$oid': '52b213b38594d8a2be17c784'}  2013-10-31T00:00:00Z
# 5    {'$oid': '52b213b38594d8a2be17c785'}  2013-10-31T00:00:00Z
# 6    {'$oid': '52b213b38594d8a2be17c786'}  2013-10-29T00:00:00Z
# 7    {'$oid': '52b213b38594d8a2be17c787'}  2013-10-29T00:00:00Z
# 8    {'$oid': '52b213b38594d8a2be17c788'}  2013-10-29T00:00:00Z
# 9    {'$oid': '52b213b38594d8a2be17c789'}  2013-10-29T00:00:00Z
# 10   {'$oid': '52b213b38594d8a2be17c78a'}  2013-10-25T00:00:00Z
# 11   {'$oid': '52b213b38594d8a2be17c78b'}  2013-10-25T00:00:00Z
# 12   {'$oid': '52b213b38594d8a2be17c78c'}  2013-10-24T00:00:00Z
# 13   {'$oid': '52b213b38594d8a2be17c78d'}  2013-10-22T00:00:00Z
# 14   {'$oid': '52b213b38594d8a2be17c78e'}  2013-10-22T00:00:00Z
# 15   {'$oid': '52b213b38594d8a2be17c78f'}  2013-10-17T00:00:00Z
# 16   {'$oid': '52b213b38594d8a2be17c790'}  2013-10-17T00:00:00Z
# 17   {'$oid': '52b213b38594d8a2be17c791'}  2013-10-16T00:00:00Z
# 492  {'$oid': '52b213b38594d8a2be17c96c'}  2012-08-21T00:00:00Z
# 493  {'$oid': '52b213b38594d8a2be17c96d'}  2012-08-21T00:00:00Z
# 494  {'$oid': '52b213b38594d8a2be17c96e'}  2012-08-17T00:00:00Z
# 495  {'$oid': '52b213b38594d8a2be17c96f'}  2012-08-10T00:00:00Z
# 496  {'$oid': '52b213b38594d8a2be17c970'}  2012-08-09T00:00:00Z
# 497  {'$oid': '52b213b38594d8a2be17c971'}  2012-08-03T00:00:00Z
# 498  {'$oid': '52b213b38594d8a2be17c972'}  2012-08-02T00:00:00Z
# 499  {'$oid': '52b213b38594d8a2be17c973'}  2012-08-02T00:00:00Z
#
#                                   countryname  \
# 0     Federal Democratic Republic of Ethiopia
# 1                         Republic of Tunisia
# 2                                      Tuvalu
# 3                           Republic of Yemen
# 4                          Kingdom of Lesotho
# 5                           Republic of Kenya
# 6                           Republic of India
# 7                  People's Republic of China
# 8                           Republic of India
# 9                          Kingdom of Morocco
# 10                    Republic of South Sudan
# 11                          Republic of India
# 12                          Republic of Ghana
# 13         Democratic Republic of Timor-Leste
# 14                Hashemite Kingdom of Jordan
# 15                                      Samoa
# 16                                      Samoa
# 17                     Republic of Madagascar
# 18                        Kingdom of Cambodia
# 19                         Kingdom of Morocco
# 20                            Kyrgyz Republic
# 21                                      Nepal
# 22                Hashemite Kingdom of Jordan
# 23                     Republic of Tajikistan
# 24                     Republic of Azerbaijan
# 25                      East Asia and Pacific
# 26           Lao People's Democratic Republic
# 27                            Pacific Islands
# 28                            Solomon Islands
# 29                     Republic of Mozambique
# ..                                        ...
# 470                       Republic of Liberia
# 471           People's Republic of Bangladesh
# 472                       Republic of Armenia
# 473                       Republic of Albania
# 474              Islamic Republic of Pakistan
# 475                     Republic of Indonesia
# 476             Socialist Republic of Vietnam
# 477                    Republic of Uzbekistan
# 478              Islamic Republic of Pakistan
# 479                     Republic of Guatemala
# 480                        Republic of Zambia
# 481                         Republic of India
# 482                         Republic of India
# 483                         Republic of India
# 484               Republic of the Philippines
# 485                                  Mongolia
# 486              Middle East and North Africa
# 487                     United Mexican States
# 488             Federative Republic of Brazil
# 489  The Independent State of Papua New Guine
# 490                                     Nepal
# 491                        West Bank and Gaza
# 492              Islamic Republic of Pakistan
# 493           People's Republic of Bangladesh
# 494                                     Nepal
# 495                                   Jamaica
# 496          Lao People's Democratic Republic
# 497                        Republic of Guinea
# 498                     Republic of Indonesia
# 499                         Republic of Kenya
#
#                      countryshortname  \
# 0                            Ethiopia
# 1                             Tunisia
# 2                              Tuvalu
# 3                  Yemen, Republic of
# 4                             Lesotho
# 5                               Kenya
# 6                               India
# 7                               China
# 8                               India
# 9                             Morocco
# 10                        South Sudan
# 11                              India
# 12                              Ghana
# 13                        Timor-Leste
# 14                             Jordan
# 15                              Samoa
# 16                              Samoa
# 17                         Madagascar
# 18                           Cambodia
# 19                            Morocco
# 20                    Kyrgyz Republic
# 21                              Nepal
# 22                             Jordan
# 23                         Tajikistan
# 24                         Azerbaijan
# 25              East Asia and Pacific
# 26   Lao People's Democratic Republic
# 27                    Pacific Islands
# 28                    Solomon Islands
# 29                         Mozambique
# ..                                ...
# 470                           Liberia
# 471                        Bangladesh
# 472                           Armenia
# 473                           Albania
# 474                          Pakistan
# 475                         Indonesia
# 476                           Vietnam
# 477                        Uzbekistan
# 478                          Pakistan
# 479                         Guatemala
# 480                            Zambia
# 481                             India
# 482                             India
# 483                             India
# 484                       Philippines
# 485                          Mongolia
# 486      Middle East and North Africa
# 487                            Mexico
# 488                            Brazil
# 489                  Papua New Guinea
# 490                             Nepal
# 491                West Bank and Gaza
# 492                          Pakistan
# 493                        Bangladesh
# 494                             Nepal
# 495                           Jamaica
# 496  Lao People's Democratic Republic
# 497                            Guinea
# 498                         Indonesia
# 499                             Kenya
#
#                                       mjtheme_namecode  \
# 0    [{'code': '8', 'name': 'Human development'}, {...
# 1    [{'code': '1', 'name': 'Economic management'},...
# 2    [{'code': '5', 'name': 'Trade and integration'...
# 3    [{'code': '7', 'name': 'Social dev/gender/incl...
# 4    [{'code': '5', 'name': 'Trade and integration'...
# 5    [{'code': '6', 'name': 'Social protection and ...
# 6    [{'code': '2', 'name': 'Public sector governan...
# 7    [{'code': '11', 'name': 'Environment and natur...
# 8    [{'code': '10', 'name': 'Rural development'}, ...
# 9    [{'code': '2', 'name': 'Public sector governan...
# 10   [{'code': '10', 'name': 'Rural development'}, ...
# 11   [{'code': '10', 'name': 'Rural development'}, ...
# 12                         [{'code': '4', 'name': ''}]
# 13   [{'code': '5', 'name': 'Trade and integration'...
# 14   [{'code': '6', 'name': 'Social protection and ...
# 15   [{'code': '10', 'name': 'Rural development'}, ...
# 16   [{'code': '10', 'name': 'Rural development'}, ...
# 17   [{'code': '8', 'name': 'Human development'}, {...
# 18   [{'code': '8', 'name': 'Human development'}, {...
# 19   [{'code': '2', 'name': 'Public sector governan...
# 20   [{'code': '7', 'name': 'Social dev/gender/incl...
# 21   [{'code': '9', 'name': 'Urban development'}, {...
# 22   [{'code': '7', 'name': 'Social dev/gender/incl...
# 23   [{'code': '8', 'name': 'Human development'}, {...
# 24   [{'code': '10', 'name': 'Rural development'}, ...
# 25   [{'code': '11', 'name': 'Environment and natur...
# 26   [{'code': '4', 'name': 'Financial and private ...
# 27   [{'code': '11', 'name': 'Environment and natur...
# 28   [{'code': '10', 'name': 'Rural development'}, ...
# 29   [{'code': '7', 'name': 'Social dev/gender/incl...
# ..                                                 ...
# 470  [{'code': '5', 'name': 'Trade and integration'...
# 471  [{'code': '10', 'name': 'Rural development'}, ...
# 472  [{'code': '11', 'name': 'Environment and natur...
# 473  [{'code': '11', 'name': 'Environment and natur...
# 474  [{'code': '9', 'name': 'Urban development'}, {...
# 475  [{'code': '4', 'name': 'Financial and private ...
# 476  [{'code': '10', 'name': 'Rural development'}, ...
# 477  [{'code': '4', 'name': 'Financial and private ...
# 478  [{'code': '2', 'name': 'Public sector governan...
# 479  [{'code': '7', 'name': 'Social dev/gender/incl...
# 480  [{'code': '2', 'name': 'Public sector governan...
# 481  [{'code': '8', 'name': 'Human development'}, {...
# 482  [{'code': '10', 'name': 'Rural development'}, ...
# 483  [{'code': '11', 'name': 'Environment and natur...
# 484  [{'code': '10', 'name': 'Rural development'}, ...
# 485  [{'code': '8', 'name': 'Human development'}, {...
# 486  [{'code': '2', 'name': 'Public sector governan...
# 487  [{'code': '11', 'name': 'Environment and natur...
# 488  [{'code': '8', 'name': 'Human development'}, {...
# 489  [{'code': '9', 'name': 'Urban development'}, {...
# 490  [{'code': '2', 'name': 'Public sector governan...
# 491  [{'code': '10', 'name': 'Rural development'}, ...
# 492  [{'code': '8', 'name': 'Human development'}, {...
# 493  [{'code': '11', 'name': 'Environment and natur...
# 494  [{'code': '6', 'name': 'Social protection and ...
# 495  [{'code': '4', 'name': 'Financial and private ...
# 496  [{'code': '8', 'name': 'Human development'}, {...
# 497  [{'code': '10', 'name': 'Rural development'}, ...
# 498  [{'code': '10', 'name': 'Rural development'}, ...
# 499  [{'code': '9', 'name': 'Urban development'}, {...
#
#                                           project_name   totalamt
# 0    Ethiopia General Education Quality Improvement...  130000000
# 1            TN: DTF Social Protection Reforms Support          0
# 2    Tuvalu Aviation Investment Project - Additiona...    6060000
# 3     Gov't and Civil Society Organization Partnership          0
# 4    Second Private Sector Competitiveness and Econ...   13100000
# 5    Additional Financing for Cash Transfers for Or...   10000000
# 6    National Highways Interconnectivity Improvemen...  500000000
# 7     China Renewable Energy Scale-Up Program Phase II          0
# 8          Rajasthan Road Sector Modernization Project  160000000
# 9               MA Accountability and Transparency DPL  200000000
# 10   Southern Sudan Emergency Food Crisis Response ...          0
# 11               Uttarakhand Disaster Recovery Project  250000000
# 12                                 GH eTransform Ghana   97000000
# 13   Timor Leste Road Climate Resilience Project - ...   40000000
# 14   NATIONAL UNIFIED REGISTRY AND OUTREACH WORKER ...          0
# 15                        Enhanced Road Access Project   20000000
# 16   Samoa Agriculture & Fisheries Cyclone Response...    5000000
# 17      Emergency Support to Education For all Project          0
# 18   Additional Financing for the Second Health Sec...          0
# 19            DTF:MA- Support New Governance Framework          0
# 20   SOCIAL COHESION THROUGH COMMUNITY-BASED DEVELO...          0
# 21            Nepal: Pro-poor Urban Regeneration Pilot          0
# 22    Jordan- Emergency Services and Social Resilience          0
# 23            Tajikistan JSDF Nutrition Grant Scale Up          0
# 24    AGRICULTURAL COMPETITIVENESS IMPROVEMENT PROJECT   34500000
# 25     Capturing Coral Reef Ecosystem Services (CCRES)          0
# 26   Lao PDR Ninth Poverty Reduction Support Operation   20000000
# 27               Pacific Aviation Safety Office Reform    2150000
# 28   Additional Financing 2 - Solomon Islands Rural...    3000000
# 29   Water Resources Development Flood Response Add...   32000000
# ..                                                 ...        ...
# 470  Road Asset Management Project - Additional Fin...   50000000
# 471  Rural Electrification and Renewable Energy Dev...  155000000
# 472           Reports to Conventions - UNCCD - Armenia          0
# 473     Land Degradation Enabling Activities - Albania          0
# 474           PK: Punjab Cities Governance Improvement  150000000
# 475    Indonesia Infrastructure Guarantee Fund Project   29600000
# 476                    Distribution Efficiency Project  448900000
# 477  Additional Financing for the Second Rural Ente...   40000000
# 478  Punjab Land Records Management and Information...   70000000
# 479  Strengthening the resilience capacity of Maya ...          0
# 480  Zambia - Extractive Industries Transparency In...          0
# 481  India: ICDS Systems Strengthening & Nutrition ...  106000000
# 482                 Karnataka Watershed Development II   60000000
# 483  IN: Development Policy Loan (DPL) to Promote I...  100000000
# 484  Multi Donor Facility - PH Mindanao Reconstruct...          0
# 485  Capacity Builiding for Emerging Infectious Dis...          0
# 486           5M: Displaced People in Jordan / Lebanon          0
# 487    Sustainable Production Systems and Biodiversity          0
# 488              RIO STATE DEVELOPMENT POLICY LOAN III  300000000
# 489    Papua New Guinea Settlement Upgrading Programme          0
# 490  Nepal PFM-MDTF Strengthening Civil Society Org...          0
# 491  Water Supply and Sanitation Improvements for W...          0
# 492  Pakistan: Promoting Girls' Education in Baloch...          0
# 493  Revision and Alignment of NAP with UNCCD 10-ye...          0
# 494  Nepal: Pilot Project for Seismic School Safety...          0
# 495  Technological Scale Up for Youth-led Urban Orn...          0
# 496                Lao Eight Poverty Reduction Support   20000000
# 497  Second Emergency Agricultural Productivity Sup...          0
# 498  Sustainable Management of Agricultural Researc...   80000000
# 499  KENYA: NATIONAL URBAN TRANSPORT IMPROVEMENT PR...  300000000
#
# [500 rows x 7 columns]

# %% [markdown]
# #### Let us find the 10 countries with the most projects

# %%
#Top ten countries with most projects
json_df_less['countryname'].value_counts().head(10)
# Out:
# Republic of Indonesia              19
# People's Republic of China         19
# Socialist Republic of Vietnam      17
# Republic of India                  16
# Republic of Yemen                  13
# People's Republic of Bangladesh    12
# Kingdom of Morocco                 12
# Nepal                              12
# Republic of Mozambique             11
# Africa                             11
# Name: countryname, dtype: int64

# %% [markdown]
# #### 10 Major Project themes

# %%
#Top ten major project themes (Some themes are counted multiple times in a single project)
wb_df_norm = json_normalize(world_bank_data, 'mjtheme_namecode')
wb_df_norm['name'].value_counts().head(10)
# Out:
# Environment and natural resources management    223
# Rural development                               202
# Human development                               197
# Public sector governance                        184
# Social protection and risk management           158
# Financial and private sector development        130
#                                                 122
# Social dev/gender/inclusion                     119
# Trade and integration                            72
# Urban development                                47
# Name: name, dtype: int64

# %% [markdown]
# ###### From the output above, we can see that there are 122 missing values.

# %%
wb_df_norm['code'].value_counts().head(10)
# Out:
# 11    250
# 10    216
# 8     210
# 2     199
# 6     168
# 4     146
# 7     130
# 5      77
# 9      50
# 1      38
# Name: code, dtype: int64

# %% [markdown]
# ###### We can see that the output above shows that just the codes are available, only the names are missing

# %% [markdown]
# #### Create a dataframe with the missing names filled in.

# %%
#Manually created dictionary for comparison purposes
theme_code_dict = {'1':'Economic management',
             '2':'Public sector governance',
             '3':'Rule of law',
             '4':'Financial and private sector development',
             '5':'Trade and integration',
             '6':'Social protection and risk management',
             '7':'Social dev/gender/inclusion',
             '8':'Human development',
             '9':'Urban development',
             '10':'Rural development',
             '11':'Environment and natural resources management',
            }
#Print dict
theme_code_dict
# Out:
# {'1': 'Economic management',
#  '2': 'Public sector governance',
#  '3': 'Rule of law',
#  '4': 'Financial and private sector development',
#  '5': 'Trade and integration',
#  '6': 'Social protection and risk management',
#  '7': 'Social dev/gender/inclusion',
#  '8': 'Human development',
#  '9': 'Urban development',
#  '10': 'Rural development',
#  '11': 'Environment and natural resources management'}

# %%
#Non-manual version
json_norm = json_normalize(world_bank_data, 'mjtheme_namecode') #Split column into own table
jn_no_empty = json_norm[json_norm.name != ''].set_index('code')['name'] #Remove empty names 
theme_code_dict = jn_no_empty.drop_duplicates().to_dict() #Drop duplicates and convert to dictionary
theme_code_dict #Print dict
# Out:
# {'8': 'Human development',
#  '1': 'Economic management',
#  '6': 'Social protection and risk management',
#  '5': 'Trade and integration',
#  '2': 'Public sector governance',
#  '11': 'Environment and natural resources management',
#  '7': 'Social dev/gender/inclusion',
#  '4': 'Financial and private sector development',
#  '10': 'Rural development',
#  '9': 'Urban development',
#  '3': 'Rule of law'}

# %%
#Function to replace mjtheme name using code from dictionary
def replace_empty(theme_dict_list):
    for theme_dict in theme_dict_list:
        if theme_dict['name'] == '':
            theme_dict['name'] = theme_code_dict[theme_dict['code']]
    return theme_dict

# %%
filled_json_df = json_df.copy(deep=True)
filled_json_df['mjtheme_namecode'].apply(replace_empty).head(10)
# Out:
# 0    {'code': '11', 'name': 'Environment and natura...
# 1    {'code': '6', 'name': 'Social protection and r...
# 2    {'code': '6', 'name': 'Social protection and r...
# 3    {'code': '7', 'name': 'Social dev/gender/inclu...
# 4    {'code': '4', 'name': 'Financial and private s...
# 5    {'code': '6', 'name': 'Social protection and r...
# 6    {'code': '4', 'name': 'Financial and private s...
# 7           {'code': '8', 'name': 'Human development'}
# 8    {'code': '7', 'name': 'Social dev/gender/inclu...
# 9    {'code': '2', 'name': 'Public sector governance'}
# Name: mjtheme_namecode, dtype: object

# %%
#Top ten major project themes (Some themes are counted multiple times in a single project)
wb_df_clean = json_normalize(world_bank_data, 'mjtheme_namecode')
wb_df_clean['name'].value_counts().head(10)
# Out:
# Environment and natural resources management    250
# Rural development                               216
# Human development                               210
# Public sector governance                        199
# Social protection and risk management           168
# Financial and private sector development        146
# Social dev/gender/inclusion                     130
# Trade and integration                            77
# Urban development                                50
# Economic management                              38
# Name: name, dtype: int64

# %%
json_df_less.head(5)
# Out:
#                                       _id     boardapprovaldate  \
# 0    {'$oid': '52b213b38594d8a2be17c780'}  2013-11-12T00:00:00Z
# 1    {'$oid': '52b213b38594d8a2be17c781'}  2013-11-04T00:00:00Z
# 2    {'$oid': '52b213b38594d8a2be17c782'}  2013-11-01T00:00:00Z
# 472                       Republic of Armenia
# 473                       Republic of Albania
# 474              Islamic Republic of Pakistan
# 475                     Republic of Indonesia
# 476             Socialist Republic of Vietnam
# 477                    Republic of Uzbekistan
# 478              Islamic Republic of Pakistan
# 479                     Republic of Guatemala
# 480                        Republic of Zambia
# 481                         Republic of India
# 482                         Republic of India
# 483                         Republic of India
# 484               Republic of the Philippines
# 485                                  Mongolia
# 486              Middle East and North Africa
# 487                     United Mexican States
# 488             Federative Republic of Brazil
# 489  The Independent State of Papua New Guine
# 490                                     Nepal
# 491                        West Bank and Gaza
# 492              Islamic Republic of Pakistan
# 493           People's Republic of Bangladesh
# 494                                     Nepal
# 495                                   Jamaica
# 496          Lao People's Democratic Republic
# 497                        Republic of Guinea
# 498                     Republic of Indonesia
# 499                         Republic of Kenya
#
#                      countryshortname  \
# 0                            Ethiopia
# 1                             Tunisia
# 2                              Tuvalu
# 3                  Yemen, Republic of
# 4                             Lesotho
# 5                               Kenya
# 6                               India
# 7                               China
# 8                               India
# 9                             Morocco
# 10                        South Sudan
# 11                              India
# 12                              Ghana
# 13                        Timor-Leste
# 14                             Jordan
# 15                              Samoa
# 16                              Samoa
# 17                         Madagascar
# 18                           Cambodia
# 19                            Morocco
# 20                    Kyrgyz Republic
# 21                              Nepal
# 22                             Jordan
# 23                         Tajikistan
# 24                         Azerbaijan
# 25              East Asia and Pacific
# 26   Lao People's Democratic Republic
# 27                    Pacific Islands
# 28                    Solomon Islands
# 29                         Mozambique
# ..                                ...
# 470                           Liberia
# 471                        Bangladesh
# 472                           Armenia
# 473                           Albania
# 474                          Pakistan
# 475                         Indonesia
# 476                           Vietnam
# 477                        Uzbekistan
# 478                          Pakistan
# 479                         Guatemala
# 480                            Zambia
# 481                             India
# 482                             India
# 483                             India
# 484                       Philippines
# 485                          Mongolia
# 486      Middle East and North Africa
# 487                            Mexico
# 488                            Brazil
# 489                  Papua New Guinea
# 490                             Nepal
# 491                West Bank and Gaza
# 492                          Pakistan
# 493                        Bangladesh
# 494                             Nepal
# 495                           Jamaica
# 496  Lao People's Democratic Republic
# 497                            Guinea
# 498                         Indonesia
# 499                             Kenya
#
#                                       mjtheme_namecode  \
# 0    [{'code': '8', 'name': 'Human development'}, {...
# 1    [{'code': '1', 'name': 'Economic management'},...
# 2    [{'code': '5', 'name': 'Trade and integration'...
# 3    [{'code': '7', 'name': 'Social dev/gender/incl...
# 4    [{'code': '5', 'name': 'Trade and integration'...
# 5    [{'code': '6', 'name': 'Social protection and ...
# 6    [{'code': '2', 'name': 'Public sector governan...
# 7    [{'code': '11', 'name': 'Environment and natur...
# 8    [{'code': '10', 'name': 'Rural development'}, ...
# 9    [{'code': '2', 'name': 'Public sector governan...
# 10   [{'code': '10', 'name': 'Rural development'}, ...
# 11   [{'code': '10', 'name': 'Rural development'}, ...
# 12   [{'code': '4', 'name': 'Financial and private ...
# 13   [{'code': '5', 'name': 'Trade and integration'...
# 14   [{'code': '6', 'name': 'Social protection and ...
# 15   [{'code': '10', 'name': 'Rural development'}, ...
# 16   [{'code': '10', 'name': 'Rural development'}, ...
# 17   [{'code': '8', 'name': 'Human development'}, {...
# 18   [{'code': '8', 'name': 'Human development'}, {...
# 19   [{'code': '2', 'name': 'Public sector governan...
# 20   [{'code': '7', 'name': 'Social dev/gender/incl...
# 21   [{'code': '9', 'name': 'Urban development'}, {...
# 22   [{'code': '7', 'name': 'Social dev/gender/incl...
# 23   [{'code': '8', 'name': 'Human development'}, {...
# 24   [{'code': '10', 'name': 'Rural development'}, ...
# 25   [{'code': '11', 'name': 'Environment and natur...
# 26   [{'code': '4', 'name': 'Financial and private ...
# 27   [{'code': '11', 'name': 'Environment and natur...
# 28   [{'code': '10', 'name': 'Rural development'}, ...
# 29   [{'code': '7', 'name': 'Social dev/gender/incl...
# ..                                                 ...
# 470  [{'code': '5', 'name': 'Trade and integration'...
# 471  [{'code': '10', 'name': 'Rural development'}, ...
# 472  [{'code': '11', 'name': 'Environment and natur...
# 473  [{'code': '11', 'name': 'Environment and natur...
# 474  [{'code': '9', 'name': 'Urban development'}, {...
# 475  [{'code': '4', 'name': 'Financial and private ...
# 476  [{'code': '10', 'name': 'Rural development'}, ...
# 477  [{'code': '4', 'name': 'Financial and private ...
# 478  [{'code': '2', 'name': 'Public sector governan...
# 479  [{'code': '7', 'name': 'Social dev/gender/incl...
# 480  [{'code': '2', 'name': 'Public sector governan...
# 481  [{'code': '8', 'name': 'Human development'}, {...
# 482  [{'code': '10', 'name': 'Rural development'}, ...
# 483  [{'code': '11', 'name': 'Environment and natur...
# 484  [{'code': '10', 'name': 'Rural development'}, ...
# 485  [{'code': '8', 'name': 'Human development'}, {...
# 486  [{'code': '2', 'name': 'Public sector governan...
# 487  [{'code': '11', 'name': 'Environment and natur...
# 488  [{'code': '8', 'name': 'Human development'}, {...
# 489  [{'code': '9', 'name': 'Urban development'}, {...
# 490  [{'code': '2', 'name': 'Public sector governan...
# 491  [{'code': '10', 'name': 'Rural development'}, ...
# 492  [{'code': '8', 'name': 'Human development'}, {...
# 493  [{'code': '11', 'name': 'Environment and natur...
# 494  [{'code': '6', 'name': 'Social protection and ...
# 495  [{'code': '4', 'name': 'Financial and private ...
# 496  [{'code': '8', 'name': 'Human development'}, {...
# 497  [{'code': '10', 'name': 'Rural development'}, ...
# 498  [{'code': '10', 'name': 'Rural development'}, ...
# 499  [{'code': '9', 'name': 'Urban development'}, {...
#
#                                           project_name   totalamt
# 0    Ethiopia General Education Quality Improvement...  130000000
# 1            TN: DTF Social Protection Reforms Support          0
# 2    Tuvalu Aviation Investment Project - Additiona...    6060000
# 3     Gov't and Civil Society Organization Partnership          0
# 4    Second Private Sector Competitiveness and Econ...   13100000
# 5    Additional Financing for Cash Transfers for Or...   10000000
# 6    National Highways Interconnectivity Improvemen...  500000000
# 7     China Renewable Energy Scale-Up Program Phase II          0
